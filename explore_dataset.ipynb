# %%
import pykeen.datasets.analysis as analysis
from pykeen.datasets import CSKG

# %%
dataset=CSKG()

# %%
print(dataset)
# Out:
# ...
# CSKG(num_entities=2087833, num_relations=58, create_inverse_triples=False)

# %%
df_relation=analysis.get_relation_count_df(dataset)
df_entity=analysis.get_entity_count_df(dataset)

# %%
df_relation
# Out:
#     relation_id    count                relation_label
# 0             0   387324                    /r/Antonym
# 1             1    25961                 /r/AtLocation
# 2             2    39551                  /r/CapableOf
# 3             3    16948                     /r/Causes
# 4             4     4496               /r/CausesDesire
# 5             5      430                  /r/CreatedBy
# 6             6     2070                  /r/DefinedAs
# 7             7   310317                /r/DerivedFrom
# 8             8     3112                    /r/Desires
# 9             9     8042               /r/DistinctFrom
# 10           10      379                    /r/Entails
# 11           11       65  /r/EtymologicallyDerivedFrom
# 12           12    30415    /r/EtymologicallyRelatedTo
# 13           13   360424                     /r/FormOf
# 14           14    16712                       /r/HasA
# 15           15   226956                 /r/HasContext
# ...

# %%
df_entity
# Out:
#          entity_id  count                     entity_label
# 0                0     29                          /c/en/0
# 1                1      1          /c/en/0.22_inch_calibre
# 2                2      1  /c/en/0.3_of_world's_population
# 3                3      1       /c/en/0.4_percent_aluminum
# 4                4      1        /c/en/0.6_percent_calcium
# ...            ...    ...                              ...
# 2087828    2087828      1               wn:winchester.n.02
# 2087829    2087829      2               wn:yellow_man.n.01
# 2087830    2087830      2             wn:yellow_woman.n.01
# 2087831    2087831      1                  wn:zamboni.n.01
# 2087832    2087832      1               wn:zidovudine.n.01
#
# [2087833 rows x 3 columns]

# %%
df_relation.to_csv("df_relation.csv")
df_entity.to_csv("df_entity.csv")
